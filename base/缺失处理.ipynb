# %%
import pandas as pd
import missingno as msno

# %%
survey=pd.read_csv('data/survey_visited.csv',keep_default_na=False,na_values='DR-1')

# %%
train=pd.read_csv('data/titanic_train.csv')
test=pd.read_csv('data/titanic_test.csv')
train.head()
train.Survived.value_counts()
train.isnull().sum()

# %%
msno.bar(train)
msno.heatmap(train)

# %%
train.dropna(subset=None,how='any',inplace=False,axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
city_day=pd.read_csv('data/city_day.csv',parse_dates=['Date'],index_col='Date')

# %%
city_day.head()
city_day.isnull().sum()
temp=city_day[['Xylene']][50:64]
# temp['Xylene']=temp['Xylene'].fillna(temp['Xylene'].mean())
# temp['Xylene']=temp['Xylene'].fillna(method='ffill')
# temp['Xylene']=temp['Xylene'].fillna(method='bfill')
temp['Xylene']=temp['Xylene'].interpolate(limit_direction='both')
temp
# Out:
#              Xylene
# Date
# 2015-02-20   7.4800
# 2015-02-21  15.4400
# 2015-02-22   8.4700
# 2015-02-23  28.4600
# 2015-02-24   6.0500
# 2015-02-25   0.8100
# 2015-02-26   0.9375
# 2015-02-27   1.0650
# 2015-02-28   1.1925
# 2015-03-01   1.3200
# 2015-03-02   0.2200
# 2015-03-03   2.2500
# 2015-03-04   1.5500
# 2015-03-05   4.1300

# %%
def my(x):
    return x+3

# %%
temp.Xylene.apply(my)
# Out:
# Date
# 2015-02-20    10.4800
# 2015-02-21    18.4400
# 2015-02-22    11.4700
# 2015-02-23    31.4600
# 2015-02-24     9.0500
# 2015-02-25     3.8100
# 2015-02-26     3.9375
# 2015-02-27     4.0650
# 2015-02-28     4.1925
# 2015-03-01     4.3200
# 2015-03-02     3.2200
# 2015-03-03     5.2500
# 2015-03-04     4.5500
# 2015-03-05     7.1300
# Name: Xylene, dtype: float64

# %%
def getVip(x):
    if x['Pclass']==1:
        return "Vip"
    return 'normal'

# %%
train['vip']=train.apply(getVip,axis=1)

# %%
train[['Pclass','vip']]
# Out:
#      Pclass     vip
# 0         3  normal
# 1         1     Vip
# 2         3  normal
# 3         1     Vip
# 4         3  normal
# ..      ...     ...
# 886       2  normal
# 887       1     Vip
# 888       3  normal
# 889       1     Vip
# 890       3  normal
#
# [891 rows x 2 columns]
