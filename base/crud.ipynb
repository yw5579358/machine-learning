# %%
import pandas as pd

# %%
movie=pd.read_csv('data/movie.csv')
movie['是否看过']=0
movie['点赞总数']=movie.actor_1_facebook_likes+movie.actor_2_facebook_likes+movie.actor_3_facebook_likes
movie.iloc[:5,-1].head()
movie.drop('点赞总数',axis=1,inplace=True)
movie.insert(loc=0,column='差值',value=movie.gross-movie.budget)
movie.head()
# Out:
#             差值  color      director_name  num_critic_for_reviews  duration  \
# 0  523505847.0  Color      James Cameron                   723.0     178.0
# 1    9404152.0  Color     Gore Verbinski                   302.0     169.0
# 2  -44925825.0  Color         Sam Mendes                   602.0     148.0
# 3  198130642.0  Color  Christopher Nolan                   813.0     164.0
# 4          NaN  Color        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross  ... language country content_rating  \
# ...

# %%
movie.director_name
movie['director_name']
movie.loc[0:1,['director_name']]
movie.iloc[0:3,-3:-1]
# Out:
#    aspect_ratio  movie_facebook_likes
# 0          1.78                 33000
# 1          2.35                     0
# 2          2.35                 85000
